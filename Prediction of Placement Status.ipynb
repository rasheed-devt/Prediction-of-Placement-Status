# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Loading train data

# %%
train_data = pd.read_excel("Train Data.xlsx")

# %%
train_data
# Out:
#      First Name           Email ID  Quantity  Price Tier  \
# 0        ANIKET     aniket@xyz.com         1         NaN
# 1     Dhanshree  dhanshree@xyz.com         1         NaN
# 2        Dhiraj     dhiraj@xyz.com         1         NaN
# 3         Pooja      pooja@xyz.com         1         NaN
# 4        Aayush     aayush@xyz.com         1         NaN
# ...         ...                ...       ...         ...
# 4889   Saif ali    saifali@xyz.com         1         NaN
# 4890    Lankesh    lankesh@xyz.com         1         NaN
# 4891     Sanjay     sanjay@xyz.com         1         NaN
# 4892   Sushmita   sushmita@xyz.com         1         NaN
# 4893      Vipul      vipul@xyz.com         1         NaN
#
#                             Ticket Type    Attendee #  Group  Order Type  \
# 0                Art of Resume Building  2.213855e+09    NaN  Free Order
# 1                Art of Resume Building  2.213859e+09    NaN  Free Order
# 2                Art of Resume Building  2.213862e+09    NaN  Free Order
# 3                Art of Resume Building  2.213988e+09    NaN  Free Order
# 4                Art of Resume Building  2.214567e+09    NaN  Free Order
# ...                                 ...           ...    ...         ...
# 4889  Data Visualization using Power BI  1.949319e+09    NaN  Free Order
# 4890  Data Visualization using Power BI  1.949328e+09    NaN  Free Order
# 4891  Data Visualization using Power BI  1.949328e+09    NaN  Free Order
# 4892  Data Visualization using Power BI  1.949330e+09    NaN  Free Order
# 4893  Data Visualization using Power BI  1.949332e+09    NaN  Free Order
#
#      Currency  Total Paid  ...  Attendee Status  \
# 0         USD           0  ...        Attending
# 1         USD           0  ...        Attending
# 2         USD           0  ...        Attending
# 3         USD           0  ...        Attending
# 4         USD           0  ...        Attending
# ...       ...         ...  ...              ...
# 4889      USD           0  ...        Attending
# 4890      USD           0  ...        Attending
# 4891      USD           0  ...        Attending
# 4892      USD           0  ...        Attending
# 4893      USD           0  ...        Attending
#
#                                            College Name  \
# 0     D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                      AP SHAH INSTITUTE OF TECHNOLOGY
# 2          Don Bosco College of Engineering Fatorda Goa
# 3              Pillai College of Engineering New Panvel
# 4                                  St Xavier's College
# ...                                                 ...
# 4889                 mit academy of engineering ,alandi
# 4890                 a. c. patil college of engineering
# 4891                                    wilson college
# 4892     ld college of engineering, ahmedabad, gujarat
# 4893  dkte society's textile and engineering institu...
#
#            How did you come to know about this event?  \
# 0                                               Email
# 1                                              Others
# 2                                               Email
# 3                                               Email
# 4     Instagram | LinkedIn | Cloud Counselage Website
# ...                                               ...
# 4889                                              NaN
# 4890                                              NaN
# 4891                                              NaN
# 4892                                              NaN
# 4893                                              NaN
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                               College
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4889                                                NaN
# 4890                                                NaN
# 4891                                                NaN
# 4892                                                NaN
# 4893                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  6.7               2             5
# 1       Students                NaN  8.2               3             2
# 2       Students                NaN  6.5               4             3
# 3       Students                NaN  8.7               2             5
# 4       Students                NaN  9.1               3             5
# ...          ...                ...  ...             ...           ...
# 4889    Students             2021.0  9.0               3             2
# 4890    Students             2021.0  7.2               4             3
# 4891    Students             2021.0  8.5               2             3
# 4892    Students             2021.0  6.5               5             5
# 4893    Students             2021.0  6.6               4             5
#
#       Placement Status
# 0               Placed
# 1           Not placed
# 2           Not placed
# 3           Not placed
# 4               Placed
# ...                ...
# 4889               NaN
# 4890               NaN
# 4891               NaN
# 4892               NaN
# 4893               NaN
#
# [4894 rows x 23 columns]

# %% [markdown]
# # Cleaning the data using emails

# %%
train_data = train_data.drop_duplicates(subset=["Email ID"])

# %%
train_data
# Out:
#      First Name           Email ID  Quantity  Price Tier  \
# 0        ANIKET     aniket@xyz.com         1         NaN
# 1     Dhanshree  dhanshree@xyz.com         1         NaN
# 2        Dhiraj     dhiraj@xyz.com         1         NaN
# 3         Pooja      pooja@xyz.com         1         NaN
# 4        Aayush     aayush@xyz.com         1         NaN
# ...         ...                ...       ...         ...
# 4829      Kevin      kevin@xyz.com         1         NaN
# 4831      Hemil      hemil@xyz.com         1         NaN
# 4832     Shitij     shitij@xyz.com         1         NaN
# 4834      dirgh      dirgh@xyz.com         1         NaN
# 4836   UTkarsha   utkarsha@xyz.com         1         NaN
#
#                                    Ticket Type    Attendee #  Group  \
# 0                       Art of Resume Building  2.213855e+09    NaN
# 1                       Art of Resume Building  2.213859e+09    NaN
# 2                       Art of Resume Building  2.213862e+09    NaN
# 3                       Art of Resume Building  2.213988e+09    NaN
# 4                       Art of Resume Building  2.214567e+09    NaN
# ...                                        ...           ...    ...
# 4829  Transformation with DevOps: The Easy Way  2.231408e+09    NaN
# 4831  Transformation with DevOps: The Easy Way  2.231440e+09    NaN
# 4832  Transformation with DevOps: The Easy Way  2.231448e+09    NaN
# 4834  Transformation with DevOps: The Easy Way  2.231489e+09    NaN
# 4836  Transformation with DevOps: The Easy Way  2.231554e+09    NaN
#
#       Order Type Currency  Total Paid  ...  Attendee Status  \
# 0     Free Order      USD           0  ...        Attending
# 1     Free Order      USD           0  ...        Attending
# 2     Free Order      USD           0  ...        Attending
# 3     Free Order      USD           0  ...        Attending
# 4     Free Order      USD           0  ...        Attending
# ...          ...      ...         ...  ...              ...
# 4829  Free Order      USD           0  ...        Attending
# 4831  Free Order      USD           0  ...        Attending
# 4832  Free Order      USD           0  ...        Attending
# 4834  Free Order      USD           0  ...        Attending
# 4836  Free Order      USD           0  ...        Attending
#
#                                            College Name  \
# 0     D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                      AP SHAH INSTITUTE OF TECHNOLOGY
# 2          Don Bosco College of Engineering Fatorda Goa
# 3              Pillai College of Engineering New Panvel
# 4                                  St Xavier's College
# ...                                                 ...
# 4829           pillai college of engineering new panvel
# 4831        vidyalankar institute of technology, mumbai
# 4832                 government polytechnic gandhinagar
# 4834          vishwakarma institute of technology, pune
# 4836      priyadarshini college of engineering, nagpur
#
#              How did you come to know about this event?  \
# 0                                                 Email
# 1                                                Others
# 2                                                 Email
# 3                                                 Email
# 4       Instagram | LinkedIn | Cloud Counselage Website
# ...                                                 ...
# 4829                                           Whatsapp
# 4831                                          Instagram
# 4832  Youtube | Facebook | Instagram | Whatsapp | Email
# 4834                                          Instagram
# 4836                                           Whatsapp
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                               College
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4829                                                NaN
# 4831                                                NaN
# 4832                                                NaN
# 4834                                                NaN
# 4836                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  6.7               2             5
# 1       Students                NaN  8.2               3             2
# 2       Students                NaN  6.5               4             3
# 3       Students                NaN  8.7               2             5
# 4       Students                NaN  9.1               3             5
# ...          ...                ...  ...             ...           ...
# 4829    Students                NaN  9.1               5             4
# 4831    Students                NaN  7.4               3             2
# 4832    Students                NaN  7.3               4             4
# 4834    Students                NaN  9.2               4             2
# 4836    Students                NaN  7.9               2             5
#
#       Placement Status
# 0               Placed
# 1           Not placed
# 2           Not placed
# 3           Not placed
# 4               Placed
# ...                ...
# 4829               NaN
# 4831               NaN
# 4832               NaN
# 4834               NaN
# 4836               NaN
#
# [1986 rows x 23 columns]

# %% [markdown]
# # Creating deep copies of your dataframe

# %%
import copy
train_data_backup = copy.deepcopy(train_data)

# %%
train_data_backup
# Out:
#      First Name           Email ID  Quantity  Price Tier  \
# 0        ANIKET     aniket@xyz.com         1         NaN
# 1     Dhanshree  dhanshree@xyz.com         1         NaN
# 2        Dhiraj     dhiraj@xyz.com         1         NaN
# 3         Pooja      pooja@xyz.com         1         NaN
# 4        Aayush     aayush@xyz.com         1         NaN
# ...         ...                ...       ...         ...
# 4829      Kevin      kevin@xyz.com         1         NaN
# 4831      Hemil      hemil@xyz.com         1         NaN
# 4832     Shitij     shitij@xyz.com         1         NaN
# 4834      dirgh      dirgh@xyz.com         1         NaN
# 4836   UTkarsha   utkarsha@xyz.com         1         NaN
#
#                                    Ticket Type    Attendee #  Group  \
# 0                       Art of Resume Building  2.213855e+09    NaN
# 1                       Art of Resume Building  2.213859e+09    NaN
# 2                       Art of Resume Building  2.213862e+09    NaN
# 3                       Art of Resume Building  2.213988e+09    NaN
# 4                       Art of Resume Building  2.214567e+09    NaN
# ...                                        ...           ...    ...
# 4829  Transformation with DevOps: The Easy Way  2.231408e+09    NaN
# 4831  Transformation with DevOps: The Easy Way  2.231440e+09    NaN
# 4832  Transformation with DevOps: The Easy Way  2.231448e+09    NaN
# 4834  Transformation with DevOps: The Easy Way  2.231489e+09    NaN
# 4836  Transformation with DevOps: The Easy Way  2.231554e+09    NaN
#
#       Order Type Currency  Total Paid  ...  Attendee Status  \
# 0     Free Order      USD           0  ...        Attending
# 1     Free Order      USD           0  ...        Attending
# 2     Free Order      USD           0  ...        Attending
# 3     Free Order      USD           0  ...        Attending
# 4     Free Order      USD           0  ...        Attending
# ...          ...      ...         ...  ...              ...
# 4829  Free Order      USD           0  ...        Attending
# 4831  Free Order      USD           0  ...        Attending
# 4832  Free Order      USD           0  ...        Attending
# 4834  Free Order      USD           0  ...        Attending
# 4836  Free Order      USD           0  ...        Attending
#
#                                            College Name  \
# 0     D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                      AP SHAH INSTITUTE OF TECHNOLOGY
# 2          Don Bosco College of Engineering Fatorda Goa
# 3              Pillai College of Engineering New Panvel
# 4                                  St Xavier's College
# ...                                                 ...
# 4829           pillai college of engineering new panvel
# 4831        vidyalankar institute of technology, mumbai
# 4832                 government polytechnic gandhinagar
# 4834          vishwakarma institute of technology, pune
# 4836      priyadarshini college of engineering, nagpur
#
#              How did you come to know about this event?  \
# 0                                                 Email
# 1                                                Others
# 2                                                 Email
# 3                                                 Email
# 4       Instagram | LinkedIn | Cloud Counselage Website
# ...                                                 ...
# 4829                                           Whatsapp
# 4831                                          Instagram
# 4832  Youtube | Facebook | Instagram | Whatsapp | Email
# 4834                                          Instagram
# 4836                                           Whatsapp
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                               College
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4829                                                NaN
# 4831                                                NaN
# 4832                                                NaN
# 4834                                                NaN
# 4836                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  6.7               2             5
# 1       Students                NaN  8.2               3             2
# 2       Students                NaN  6.5               4             3
# 3       Students                NaN  8.7               2             5
# 4       Students                NaN  9.1               3             5
# ...          ...                ...  ...             ...           ...
# 4829    Students                NaN  9.1               5             4
# 4831    Students                NaN  7.4               3             2
# 4832    Students                NaN  7.3               4             4
# 4834    Students                NaN  9.2               4             2
# 4836    Students                NaN  7.9               2             5
#
#       Placement Status
# 0               Placed
# 1           Not placed
# 2           Not placed
# 3           Not placed
# 4               Placed
# ...                ...
# 4829               NaN
# 4831               NaN
# 4832               NaN
# 4834               NaN
# 4836               NaN
#
# [1986 rows x 23 columns]

# %% [markdown]
# # Selecting only useful columns

# %%
useful_columns = ["Ticket Type", "Attendee #", "Attendee Status", "College Name",
                  "Designation", "Year of Graduation", "CGPA", "Speaking Skills", 
                  "ML Knowledge", "Placement Status"]

train_data = train_data[useful_columns]

# %%
train_data
# Out:
#                                    Ticket Type    Attendee # Attendee Status  \
# 0                       Art of Resume Building  2.213855e+09       Attending
# 1                       Art of Resume Building  2.213859e+09       Attending
# 2                       Art of Resume Building  2.213862e+09       Attending
# 3                       Art of Resume Building  2.213988e+09       Attending
# 4                       Art of Resume Building  2.214567e+09       Attending
# ...                                        ...           ...             ...
# 4829  Transformation with DevOps: The Easy Way  2.231408e+09       Attending
# 4831  Transformation with DevOps: The Easy Way  2.231440e+09       Attending
# 4832  Transformation with DevOps: The Easy Way  2.231448e+09       Attending
# 4834  Transformation with DevOps: The Easy Way  2.231489e+09       Attending
# 4836  Transformation with DevOps: The Easy Way  2.231554e+09       Attending
#
#                                            College Name Designation  \
# 0     D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...    Students
# 1                      AP SHAH INSTITUTE OF TECHNOLOGY     Students
# 2          Don Bosco College of Engineering Fatorda Goa    Students
# 3              Pillai College of Engineering New Panvel    Students
# 4                                  St Xavier's College     Students
# ...                                                 ...         ...
# 4829           pillai college of engineering new panvel    Students
# 4831        vidyalankar institute of technology, mumbai    Students
# 4832                 government polytechnic gandhinagar    Students
# 4834          vishwakarma institute of technology, pune    Students
# 4836      priyadarshini college of engineering, nagpur     Students
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge Placement Status
# 0                    NaN   6.7                2             5           Placed
# 1                    NaN   8.2                3             2       Not placed
# 2                    NaN   6.5                4             3       Not placed
# 3                    NaN   8.7                2             5       Not placed
# 4                    NaN   9.1                3             5           Placed
# ...                  ...   ...              ...           ...              ...
# 4829                 NaN   9.1                5             4              NaN
# 4831                 NaN   7.4                3             2              NaN
# 4832                 NaN   7.3                4             4              NaN
# 4834                 NaN   9.2                4             2              NaN
# 4836                 NaN   7.9                2             5              NaN
#
# [1986 rows x 10 columns]

# %% [markdown]
# # Converting categorical columns to numeric using Label Encoding

# %%
categorical_columns = ["Ticket Type", "Attendee Status",
                       "College Name", "Designation",
                       "Placement Status"]

for column in categorical_columns:
    le = LabelEncoder()
    train_data[column] = le.fit_transform(train_data[column])
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\1010561202.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = le.fit_transform(train_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\1010561202.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = le.fit_transform(train_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\1010561202.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = le.fit_transform(train_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\1010561202.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = le.fit_transform(train_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\1010561202.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = le.fit_transform(train_data[column])

# %%
train_data[column]
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4829    2
# 4831    2
# 4832    2
# 4834    2
# 4836    2
# Name: Placement Status, Length: 1986, dtype: int32

# %%
train_data
# Out:
#       Ticket Type    Attendee #  Attendee Status  College Name  Designation  \
# 0               0  2.213855e+09                0             5           31
# 1               0  2.213859e+09                0             2           31
# 2               0  2.213862e+09                0             7           31
# 3               0  2.213988e+09                0            16           31
# 4               0  2.214567e+09                0            20           31
# ...           ...           ...              ...           ...          ...
# 4829           15  2.231408e+09                0            44           31
# 4831           15  2.231440e+09                0            52           31
# 4832           15  2.231448e+09                0            36           31
# 4834           15  2.231489e+09                0            53           31
# 4836           15  2.231554e+09                0            45           31
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge  \
# 0                    NaN   6.7                2             5
# 1                    NaN   8.2                3             2
# 2                    NaN   6.5                4             3
# 3                    NaN   8.7                2             5
# 4                    NaN   9.1                3             5
# ...                  ...   ...              ...           ...
# 4829                 NaN   9.1                5             4
# 4831                 NaN   7.4                3             2
# 4832                 NaN   7.3                4             4
# 4834                 NaN   9.2                4             2
# 4836                 NaN   7.9                2             5
#
#       Placement Status
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# ...                ...
# 4829                 2
# 4831                 2
# 4832                 2
# 4834                 2
# 4836                 2
#
# [1986 rows x 10 columns]

# %% [markdown]
# # Separating features (x_train) and target (y_train)

# %%
x_train = train_data.drop("Placement Status", axis=1)
y_train = train_data["Placement Status"]

# %%
x_train
# Out:
#       Ticket Type    Attendee #  Attendee Status  College Name  Designation  \
# 0               0  2.213855e+09                0             5           31
# 1               0  2.213859e+09                0             2           31
# 2               0  2.213862e+09                0             7           31
# 3               0  2.213988e+09                0            16           31
# 4               0  2.214567e+09                0            20           31
# ...           ...           ...              ...           ...          ...
# 4829           15  2.231408e+09                0            44           31
# 4831           15  2.231440e+09                0            52           31
# 4832           15  2.231448e+09                0            36           31
# 4834           15  2.231489e+09                0            53           31
# 4836           15  2.231554e+09                0            45           31
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge
# 0                    NaN   6.7                2             5
# 1                    NaN   8.2                3             2
# 2                    NaN   6.5                4             3
# 3                    NaN   8.7                2             5
# 4                    NaN   9.1                3             5
# ...                  ...   ...              ...           ...
# 4829                 NaN   9.1                5             4
# 4831                 NaN   7.4                3             2
# 4832                 NaN   7.3                4             4
# 4834                 NaN   9.2                4             2
# 4836                 NaN   7.9                2             5
#
# [1986 rows x 9 columns]

# %%
y_train
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4829    2
# 4831    2
# 4832    2
# 4834    2
# 4836    2
# Name: Placement Status, Length: 1986, dtype: int32

# %% [markdown]
# # Spliting the data into train and validation sets

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# # Importing the Imputer

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Instantiating the imputer

# %%
imputer = SimpleImputer(strategy='mean')

# %% [markdown]
# # Fitting and transforming the imputer on the training data

# %%
x_train_imputed = imputer.fit_transform(x_train)

# %%
x_train_imputed
# Out:
# array([[1.20000000e+01, 1.96419430e+09, 0.00000000e+00, ...,
#         7.20000000e+00, 2.00000000e+00, 2.00000000e+00],
#        [2.00000000e+00, 2.48989617e+09, 0.00000000e+00, ...,
#         7.90000000e+00, 5.00000000e+00, 5.00000000e+00],
#        [6.00000000e+00, 1.98444520e+09, 0.00000000e+00, ...,
#         7.60000000e+00, 2.00000000e+00, 2.00000000e+00],
#        ...,
#        [4.00000000e+00, 2.04816374e+09, 0.00000000e+00, ...,
#         9.20000000e+00, 5.00000000e+00, 5.00000000e+00],
#        [8.00000000e+00, 4.08945010e+09, 0.00000000e+00, ...,
#         8.70000000e+00, 3.00000000e+00, 3.00000000e+00],
#        [6.00000000e+00, 1.98637959e+09, 0.00000000e+00, ...,
#         7.30000000e+00, 5.00000000e+00, 5.00000000e+00]])

# %%
x_train
# Out:
#       Ticket Type    Attendee #  Attendee Status  College Name  Designation  \
# 4356           12  1.964194e+09                0            54           31
# 526             2           NaN                0            37           31
# 1858            6  1.984445e+09                0            41           31
# 2406            5  2.022820e+09                0            54           31
# 917             1  2.348718e+09                0            29           31
# ...           ...           ...              ...           ...          ...
# 2134            6  1.986424e+09                0            37           31
# 2590            5  2.025785e+09                0            28           31
# 1515            4  2.048164e+09                0            22            2
# 3051            8  4.089450e+09                0            53           31
# 2130            6  1.986380e+09                0            35           31
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge
# 4356              2023.0   7.2                2             2
# 526                  NaN   7.9                5             5
# 1858                 NaN   7.6                2             2
# 2406              2020.0   9.4                2             3
# 917                  NaN   8.4                2             2
# ...                  ...   ...              ...           ...
# 2134                 NaN   7.9                2             2
# 2590              2020.0   8.6                3             2
# 1515                 NaN   9.2                5             5
# 3051                 NaN   8.7                3             3
# 2130                 NaN   7.3                5             5
#
# [1588 rows x 9 columns]

# %%
y_train
# Out:
# 4356    2
# 526     0
# 1858    2
# 2406    2
# 917     0
#        ..
# 2134    2
# 2590    2
# 1515    2
# 3051    2
# 2130    2
# Name: Placement Status, Length: 1588, dtype: int32

# %% [markdown]
# # Model that can handle missing values natively

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

model = HistGradientBoostingClassifier()
model.fit(x_train, y_train)
# Out:
# HistGradientBoostingClassifier()

# %% [markdown]
# # Loading test data

# %%
test_data = pd.read_excel("Test Data.xlsx")

# %%
test_data
# Out:
#       First Name            Email ID  Quantity  Price Tier  \
# 0         Sahil        sahil@xyz.com         1         NaN
# 1        Amrita       amrita@xyz.com         1         NaN
# 2          Mamta       mamta@xyz.com         1         NaN
# 3     Bhagyashri  bhagyashri@xyz.com         1         NaN
# 4      Divyanshu   divyanshu@xyz.com         1         NaN
# ...          ...                 ...       ...         ...
# 3791    Saif ali     saifali@xyz.com         1         NaN
# 3792     Lankesh     lankesh@xyz.com         1         NaN
# 3793      Sanjay      sanjay@xyz.com         1         NaN
# 3794    Sushmita    sushmita@xyz.com         1         NaN
# 3795       Vipul       vipul@xyz.com         1         NaN
#
#                             Ticket Type    Attendee #  Group  Order Type  \
# 0                       Hello ML and DL  2.293940e+09    NaN  Free Order
# 1                       Hello ML and DL  2.293941e+09    NaN  Free Order
# 2                       Hello ML and DL  2.293941e+09    NaN  Free Order
# 3                       Hello ML and DL  2.293946e+09    NaN  Free Order
# 4                       Hello ML and DL  2.293956e+09    NaN  Free Order
# ...                                 ...           ...    ...         ...
# 3791  Data Visualization using Power BI  1.949319e+09    NaN  Free Order
# 3792  Data Visualization using Power BI  1.949328e+09    NaN  Free Order
# 3793  Data Visualization using Power BI  1.949328e+09    NaN  Free Order
# 3794  Data Visualization using Power BI  1.949330e+09    NaN  Free Order
# 3795  Data Visualization using Power BI  1.949332e+09    NaN  Free Order
#
#      Currency  Total Paid  ...  Attendee Status  \
# 0         USD           0  ...        Attending
# 1         USD           0  ...        Attending
# 2         USD           0  ...        Attending
# 3         USD           0  ...        Attending
# 4         USD           0  ...        Attending
# ...       ...         ...  ...              ...
# 3791      USD           0  ...        Attending
# 3792      USD           0  ...        Attending
# 3793      USD           0  ...        Attending
# 3794      USD           0  ...        Attending
# 3795      USD           0  ...        Attending
#
#                                            College Name  \
# 0               symbiosis institute of technology, pune
# 1                    mit academy of engineering ,alandi
# 2                    a. c. patil college of engineering
# 3                                       wilson college
# 4        ld college of engineering, ahmedabad, gujarat
# ...                                                 ...
# 3791                 mit academy of engineering ,alandi
# 3792                 a. c. patil college of engineering
# 3793                                    wilson college
# 3794     ld college of engineering, ahmedabad, gujarat
# 3795  dkte society's textile and engineering institu...
#
#       How did you come to know about this event?  \
# 0                                       Whatsapp
# 1                                       Whatsapp
# 2                                       Whatsapp
# 3                                         Others
# 4                                       Whatsapp
# ...                                          ...
# 3791                                         NaN
# 3792                                         NaN
# 3793                                         NaN
# 3794                                         NaN
# 3795                                         NaN
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3791                                                NaN
# 3792                                                NaN
# 3793                                                NaN
# 3794                                                NaN
# 3795                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  7.8               3             3
# 1       Students                NaN  9.1               3             3
# 2       Students                NaN  6.9               2             2
# 3       Students                NaN  8.4               4             4
# 4       Students                NaN  6.7               5             5
# ...          ...                ...  ...             ...           ...
# 3791    Students             2021.0  9.0               3             2
# 3792    Students             2021.0  7.2               4             3
# 3793    Students             2021.0  8.5               2             3
# 3794    Students             2021.0  6.5               5             5
# 3795    Students             2021.0  6.6               4             5
#
#       Placement Status
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3791               NaN
# 3792               NaN
# 3793               NaN
# 3794               NaN
# 3795               NaN
#
# [3796 rows x 23 columns]

# %% [markdown]
# # Cleaning the data using emails

# %%
test_data = test_data.drop_duplicates(subset=["Email ID"])

# %%
test_data
# Out:
#         First Name              Email ID  Quantity  Price Tier  \
# 0           Sahil          sahil@xyz.com         1         NaN
# 1          Amrita         amrita@xyz.com         1         NaN
# 2            Mamta         mamta@xyz.com         1         NaN
# 3       Bhagyashri    bhagyashri@xyz.com         1         NaN
# 4        Divyanshu     divyanshu@xyz.com         1         NaN
# ...            ...                   ...       ...         ...
# 3685  Suryaprakash  suryaprakash@xyz.com         1         NaN
# 3687       Rishika       rishika@xyz.com         1         NaN
# 3692      Saif ali       saifali@xyz.com         1         NaN
# 3693       Lankesh       lankesh@xyz.com         1         NaN
# 3695      Sushmita      sushmita@xyz.com         1         NaN
#
#                                    Ticket Type    Attendee #  Group  \
# 0                              Hello ML and DL  2.293940e+09    NaN
# 1                              Hello ML and DL  2.293941e+09    NaN
# 2                              Hello ML and DL  2.293941e+09    NaN
# 3                              Hello ML and DL  2.293946e+09    NaN
# 4                              Hello ML and DL  2.293956e+09    NaN
# ...                                        ...           ...    ...
# 3685  Transformation with DevOps: The Easy Way  2.230416e+09    NaN
# 3687  Transformation with DevOps: The Easy Way  2.230905e+09    NaN
# 3692  Transformation with DevOps: The Easy Way  2.231008e+09    NaN
# 3693  Transformation with DevOps: The Easy Way  2.231016e+09    NaN
# 3695  Transformation with DevOps: The Easy Way  2.231053e+09    NaN
#
#       Order Type Currency  Total Paid  ...  Attendee Status  \
# 0     Free Order      USD           0  ...        Attending
# 1     Free Order      USD           0  ...        Attending
# 2     Free Order      USD           0  ...        Attending
# 3     Free Order      USD           0  ...        Attending
# 4     Free Order      USD           0  ...        Attending
# ...          ...      ...         ...  ...              ...
# 3685  Free Order      USD           0  ...        Attending
# 3687  Free Order      USD           0  ...        Attending
# 3692  Free Order      USD           0  ...        Attending
# 3693  Free Order      USD           0  ...        Attending
# 3695  Free Order      USD           0  ...        Attending
#
#                                            College Name  \
# 0               symbiosis institute of technology, pune
# 1                    mit academy of engineering ,alandi
# 2                    a. c. patil college of engineering
# 3                                       wilson college
# 4        ld college of engineering, ahmedabad, gujarat
# ...                                                 ...
# 3685       don bosco college of engineering fatorda goa
# 3687                               st xavier's college
# 3692  dkte society's textile and engineering institu...
# 3693     ld college of engineering, ahmedabad, gujarat
# 3695                 government polytechnic gandhinagar
#
#       How did you come to know about this event?  \
# 0                                       Whatsapp
# 1                                       Whatsapp
# 2                                       Whatsapp
# 3                                         Others
# 4                                       Whatsapp
# ...                                          ...
# 3685                                   Instagram
# 3687                                    Whatsapp
# 3692                                    Whatsapp
# 3693                                   Instagram
# 3695                                   Instagram
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3685                                                NaN
# 3687                                                NaN
# 3692                                                NaN
# 3693                                                NaN
# 3695                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  7.8               3             3
# 1       Students                NaN  9.1               3             3
# 2       Students                NaN  6.9               2             2
# 3       Students                NaN  8.4               4             4
# 4       Students                NaN  6.7               5             5
# ...          ...                ...  ...             ...           ...
# 3685    Students                NaN  8.0               3             3
# 3687    Students                NaN  8.5               5             5
# 3692    Students                NaN  8.8               3             3
# 3693    Students                NaN  9.3               4             4
# 3695    Students                NaN  6.5               4             4
#
#       Placement Status
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3685               NaN
# 3687               NaN
# 3692               NaN
# 3693               NaN
# 3695               NaN
#
# [2321 rows x 23 columns]

# %% [markdown]
# # Creating deep copies of your dataframe

# %%
test_data_backup = copy.deepcopy(test_data)

# %%
test_data_backup
# Out:
#         First Name              Email ID  Quantity  Price Tier  \
# 0           Sahil          sahil@xyz.com         1         NaN
# 1          Amrita         amrita@xyz.com         1         NaN
# 2            Mamta         mamta@xyz.com         1         NaN
# 3       Bhagyashri    bhagyashri@xyz.com         1         NaN
# 4        Divyanshu     divyanshu@xyz.com         1         NaN
# ...            ...                   ...       ...         ...
# 3685  Suryaprakash  suryaprakash@xyz.com         1         NaN
# 3687       Rishika       rishika@xyz.com         1         NaN
# 3692      Saif ali       saifali@xyz.com         1         NaN
# 3693       Lankesh       lankesh@xyz.com         1         NaN
# 3695      Sushmita      sushmita@xyz.com         1         NaN
#
#                                    Ticket Type    Attendee #  Group  \
# 0                              Hello ML and DL  2.293940e+09    NaN
# 1                              Hello ML and DL  2.293941e+09    NaN
# 2                              Hello ML and DL  2.293941e+09    NaN
# 3                              Hello ML and DL  2.293946e+09    NaN
# 4                              Hello ML and DL  2.293956e+09    NaN
# ...                                        ...           ...    ...
# 3685  Transformation with DevOps: The Easy Way  2.230416e+09    NaN
# 3687  Transformation with DevOps: The Easy Way  2.230905e+09    NaN
# 3692  Transformation with DevOps: The Easy Way  2.231008e+09    NaN
# 3693  Transformation with DevOps: The Easy Way  2.231016e+09    NaN
# 3695  Transformation with DevOps: The Easy Way  2.231053e+09    NaN
#
#       Order Type Currency  Total Paid  ...  Attendee Status  \
# 0     Free Order      USD           0  ...        Attending
# 1     Free Order      USD           0  ...        Attending
# 2     Free Order      USD           0  ...        Attending
# 3     Free Order      USD           0  ...        Attending
# 4     Free Order      USD           0  ...        Attending
# ...          ...      ...         ...  ...              ...
# 3685  Free Order      USD           0  ...        Attending
# 3687  Free Order      USD           0  ...        Attending
# 3692  Free Order      USD           0  ...        Attending
# 3693  Free Order      USD           0  ...        Attending
# 3695  Free Order      USD           0  ...        Attending
#
#                                            College Name  \
# 0               symbiosis institute of technology, pune
# 1                    mit academy of engineering ,alandi
# 2                    a. c. patil college of engineering
# 3                                       wilson college
# 4        ld college of engineering, ahmedabad, gujarat
# ...                                                 ...
# 3685       don bosco college of engineering fatorda goa
# 3687                               st xavier's college
# 3692  dkte society's textile and engineering institu...
# 3693     ld college of engineering, ahmedabad, gujarat
# 3695                 government polytechnic gandhinagar
#
#       How did you come to know about this event?  \
# 0                                       Whatsapp
# 1                                       Whatsapp
# 2                                       Whatsapp
# 3                                         Others
# 4                                       Whatsapp
# ...                                          ...
# 3685                                   Instagram
# 3687                                    Whatsapp
# 3692                                    Whatsapp
# 3693                                   Instagram
# 3695                                   Instagram
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3685                                                NaN
# 3687                                                NaN
# 3692                                                NaN
# 3693                                                NaN
# 3695                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  7.8               3             3
# 1       Students                NaN  9.1               3             3
# 2       Students                NaN  6.9               2             2
# 3       Students                NaN  8.4               4             4
# 4       Students                NaN  6.7               5             5
# ...          ...                ...  ...             ...           ...
# 3685    Students                NaN  8.0               3             3
# 3687    Students                NaN  8.5               5             5
# 3692    Students                NaN  8.8               3             3
# 3693    Students                NaN  9.3               4             4
# 3695    Students                NaN  6.5               4             4
#
#       Placement Status
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3685               NaN
# 3687               NaN
# 3692               NaN
# 3693               NaN
# 3695               NaN
#
# [2321 rows x 23 columns]

# %% [markdown]
# # Selecting only useful columns

# %%
useful_columns = ["Ticket Type", "Attendee #", "Attendee Status", "College Name",
                  "Designation", "Year of Graduation", "CGPA", "Speaking Skills", "ML Knowledge"]

test_data = test_data[useful_columns]

# %%
test_data
# Out:
#                                    Ticket Type    Attendee # Attendee Status  \
# 0                              Hello ML and DL  2.293940e+09       Attending
# 1                              Hello ML and DL  2.293941e+09       Attending
# 2                              Hello ML and DL  2.293941e+09       Attending
# 3                              Hello ML and DL  2.293946e+09       Attending
# 4                              Hello ML and DL  2.293956e+09       Attending
# ...                                        ...           ...             ...
# 3685  Transformation with DevOps: The Easy Way  2.230416e+09       Attending
# 3687  Transformation with DevOps: The Easy Way  2.230905e+09       Attending
# 3692  Transformation with DevOps: The Easy Way  2.231008e+09       Attending
# 3693  Transformation with DevOps: The Easy Way  2.231016e+09       Attending
# 3695  Transformation with DevOps: The Easy Way  2.231053e+09       Attending
#
#                                            College Name Designation  \
# 0               symbiosis institute of technology, pune    Students
# 1                    mit academy of engineering ,alandi    Students
# 2                    a. c. patil college of engineering    Students
# 3                                       wilson college     Students
# 4        ld college of engineering, ahmedabad, gujarat     Students
# ...                                                 ...         ...
# 3685       don bosco college of engineering fatorda goa    Students
# 3687                               st xavier's college     Students
# 3692  dkte society's textile and engineering institu...    Students
# 3693     ld college of engineering, ahmedabad, gujarat     Students
# 3695                 government polytechnic gandhinagar    Students
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge
# 0                    NaN   7.8                3             3
# 1                    NaN   9.1                3             3
# 2                    NaN   6.9                2             2
# 3                    NaN   8.4                4             4
# 4                    NaN   6.7                5             5
# ...                  ...   ...              ...           ...
# 3685                 NaN   8.0                3             3
# 3687                 NaN   8.5                5             5
# 3692                 NaN   8.8                3             3
# 3693                 NaN   9.3                4             4
# 3695                 NaN   6.5                4             4
#
# [2321 rows x 9 columns]

# %% [markdown]
# # Converting categorical columns to numeric using Label Encoding

# %%
categorical_columns = ["Ticket Type", "Attendee Status",
                       "College Name", "Designation"
                       ]

for column in categorical_columns:
    le = LabelEncoder()
    test_data[column] = le.fit_transform(test_data[column])
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\276730625.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = le.fit_transform(test_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\276730625.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = le.fit_transform(test_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\276730625.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = le.fit_transform(test_data[column])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_10172\276730625.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = le.fit_transform(test_data[column])

# %%
test_data[column]
# Out:
# 0       45
# 1       45
# 2       45
# 3       45
# 4       45
#         ..
# 3685    45
# 3687    45
# 3692    45
# 3693    45
# 3695    45
# Name: Designation, Length: 2321, dtype: int32

# %%
test_data
# Out:
#       Ticket Type    Attendee #  Attendee Status  College Name  Designation  \
# 0               0  2.293940e+09                0            49           45
# 1               0  2.293941e+09                0            41           45
# 2               0  2.293941e+09                0            27           45
# 3               0  2.293946e+09                0            53           45
# 4               0  2.293956e+09                0            39           45
# ...           ...           ...              ...           ...          ...
# 3685           11  2.230416e+09                0            34           45
# 3687           11  2.230905e+09                0            47           45
# 3692           11  2.231008e+09                0            33           45
# 3693           11  2.231016e+09                0            39           45
# 3695           11  2.231053e+09                0            36           45
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge
# 0                    NaN   7.8                3             3
# 1                    NaN   9.1                3             3
# 2                    NaN   6.9                2             2
# 3                    NaN   8.4                4             4
# 4                    NaN   6.7                5             5
# ...                  ...   ...              ...           ...
# 3685                 NaN   8.0                3             3
# 3687                 NaN   8.5                5             5
# 3692                 NaN   8.8                3             3
# 3693                 NaN   9.3                4             4
# 3695                 NaN   6.5                4             4
#
# [2321 rows x 9 columns]

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(x_val)
accuracy = accuracy_score(y_val, y_pred)
print("Validation Accuracy:", accuracy)
# Out:
# Validation Accuracy: 0.8241206030150754

# %%
train_data
# Out:
#       Ticket Type    Attendee #  Attendee Status  College Name  Designation  \
# 0               0  2.213855e+09                0             5           31
# 1               0  2.213859e+09                0             2           31
# 2               0  2.213862e+09                0             7           31
# 3               0  2.213988e+09                0            16           31
# 4               0  2.214567e+09                0            20           31
# ...           ...           ...              ...           ...          ...
# 4829           15  2.231408e+09                0            44           31
# 4831           15  2.231440e+09                0            52           31
# 4832           15  2.231448e+09                0            36           31
# 4834           15  2.231489e+09                0            53           31
# 4836           15  2.231554e+09                0            45           31
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge  \
# 0                    NaN   6.7                2             5
# 1                    NaN   8.2                3             2
# 2                    NaN   6.5                4             3
# 3                    NaN   8.7                2             5
# 4                    NaN   9.1                3             5
# ...                  ...   ...              ...           ...
# 4829                 NaN   9.1                5             4
# 4831                 NaN   7.4                3             2
# 4832                 NaN   7.3                4             4
# 4834                 NaN   9.2                4             2
# 4836                 NaN   7.9                2             5
#
#       Placement Status
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# ...                ...
# 4829                 2
# 4831                 2
# 4832                 2
# 4834                 2
# 4836                 2
#
# [1986 rows x 10 columns]

# %%
test_data
# Out:
#       Ticket Type    Attendee #  Attendee Status  College Name  Designation  \
# 0               0  2.293940e+09                0            49           45
# 1               0  2.293941e+09                0            41           45
# 2               0  2.293941e+09                0            27           45
# 3               0  2.293946e+09                0            53           45
# 4               0  2.293956e+09                0            39           45
# ...           ...           ...              ...           ...          ...
# 3685           11  2.230416e+09                0            34           45
# 3687           11  2.230905e+09                0            47           45
# 3692           11  2.231008e+09                0            33           45
# 3693           11  2.231016e+09                0            39           45
# 3695           11  2.231053e+09                0            36           45
#
#       Year of Graduation  CGPA  Speaking Skills  ML Knowledge
# 0                    NaN   7.8                3             3
# 1                    NaN   9.1                3             3
# 2                    NaN   6.9                2             2
# 3                    NaN   8.4                4             4
# 4                    NaN   6.7                5             5
# ...                  ...   ...              ...           ...
# 3685                 NaN   8.0                3             3
# 3687                 NaN   8.5                5             5
# 3692                 NaN   8.8                3             3
# 3693                 NaN   9.3                4             4
# 3695                 NaN   6.5                4             4
#
# [2321 rows x 9 columns]

# %%
test_data_backup
# Out:
#         First Name              Email ID  Quantity  Price Tier  \
# 0           Sahil          sahil@xyz.com         1         NaN
# 1          Amrita         amrita@xyz.com         1         NaN
# 2            Mamta         mamta@xyz.com         1         NaN
# 3       Bhagyashri    bhagyashri@xyz.com         1         NaN
# 4        Divyanshu     divyanshu@xyz.com         1         NaN
# ...            ...                   ...       ...         ...
# 3685  Suryaprakash  suryaprakash@xyz.com         1         NaN
# 3687       Rishika       rishika@xyz.com         1         NaN
# 3692      Saif ali       saifali@xyz.com         1         NaN
# 3693       Lankesh       lankesh@xyz.com         1         NaN
# 3695      Sushmita      sushmita@xyz.com         1         NaN
#
#                                    Ticket Type    Attendee #  Group  \
# 0                              Hello ML and DL  2.293940e+09    NaN
# 1                              Hello ML and DL  2.293941e+09    NaN
# 2                              Hello ML and DL  2.293941e+09    NaN
# 3                              Hello ML and DL  2.293946e+09    NaN
# 4                              Hello ML and DL  2.293956e+09    NaN
# ...                                        ...           ...    ...
# 3685  Transformation with DevOps: The Easy Way  2.230416e+09    NaN
# 3687  Transformation with DevOps: The Easy Way  2.230905e+09    NaN
# 3692  Transformation with DevOps: The Easy Way  2.231008e+09    NaN
# 3693  Transformation with DevOps: The Easy Way  2.231016e+09    NaN
# 3695  Transformation with DevOps: The Easy Way  2.231053e+09    NaN
#
#       Order Type Currency  Total Paid  ...  Attendee Status  \
# 0     Free Order      USD           0  ...        Attending
# 1     Free Order      USD           0  ...        Attending
# 2     Free Order      USD           0  ...        Attending
# 3     Free Order      USD           0  ...        Attending
# 4     Free Order      USD           0  ...        Attending
# ...          ...      ...         ...  ...              ...
# 3685  Free Order      USD           0  ...        Attending
# 3687  Free Order      USD           0  ...        Attending
# 3692  Free Order      USD           0  ...        Attending
# 3693  Free Order      USD           0  ...        Attending
# 3695  Free Order      USD           0  ...        Attending
#
#                                            College Name  \
# 0               symbiosis institute of technology, pune
# 1                    mit academy of engineering ,alandi
# 2                    a. c. patil college of engineering
# 3                                       wilson college
# 4        ld college of engineering, ahmedabad, gujarat
# ...                                                 ...
# 3685       don bosco college of engineering fatorda goa
# 3687                               st xavier's college
# 3692  dkte society's textile and engineering institu...
# 3693     ld college of engineering, ahmedabad, gujarat
# 3695                 government polytechnic gandhinagar
#
#       How did you come to know about this event?  \
# 0                                       Whatsapp
# 1                                       Whatsapp
# 2                                       Whatsapp
# 3                                         Others
# 4                                       Whatsapp
# ...                                          ...
# 3685                                   Instagram
# 3687                                    Whatsapp
# 3692                                    Whatsapp
# 3693                                   Instagram
# 3695                                   Instagram
#
#      Specify in Others (how did you come to know about this event)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3685                                                NaN
# 3687                                                NaN
# 3692                                                NaN
# 3693                                                NaN
# 3695                                                NaN
#
#      Designation Year of Graduation CGPA Speaking Skills  ML Knowledge  \
# 0       Students                NaN  7.8               3             3
# 1       Students                NaN  9.1               3             3
# 2       Students                NaN  6.9               2             2
# 3       Students                NaN  8.4               4             4
# 4       Students                NaN  6.7               5             5
# ...          ...                ...  ...             ...           ...
# 3685    Students                NaN  8.0               3             3
# 3687    Students                NaN  8.5               5             5
# 3692    Students                NaN  8.8               3             3
# 3693    Students                NaN  9.3               4             4
# 3695    Students                NaN  6.5               4             4
#
#       Placement Status
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3685               NaN
# 3687               NaN
# 3692               NaN
# 3693               NaN
# 3695               NaN
#
# [2321 rows x 23 columns]

# %% [markdown]
# # Making predictions on test data

# %%
predictions = model.predict(test_data)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %% [markdown]
# # Saving predictions to a separate excel file

# %%
output_df = pd.DataFrame({"First Name": test_data_backup["First Name"], "Email ID": test_data_backup["Email ID"], **test_data, "Placement Status": predictions})
output_df.to_excel("Prediction of Placement Status.xlsx", index=False)
